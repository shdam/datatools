# %% [markdown]
# # Project 1: Customer Database
# **This is the first of three mandatory projects to be handed in as part of the assessment for the course 02807 Computational Tools for Data Science at Technical University of Denmark, autumn 2019.**
#
# #### Practical info
# - **The project is to be done in groups of at most 3 students**
# - **Each group has to hand in _one_ Jupyter notebook (this notebook) with their solution**
# - **The hand-in of the notebook is due 2019-10-13, 23:59 on DTU Inside**
#
# #### Your solution
# - **Your solution should be in Python**
# - **For each question you may use as many cells for your solution as you like**
# - **You should document your solution and explain the choices you've made (for example by using multiple cells and use Markdown to assist the reader of the notebook)**
# - **You should not remove the problem statements, and you should not modify the structure of the notebook**
# - **Your notebook should be runnable, i.e., clicking [>>] in Jupyter should generate the result that you want to be assessed**
# - **You are not expected to use machine learning to solve any of the exercises**
# - **You will be assessed according to correctness and readability of your code, choice of solution, choice of tools and libraries, and documentation of your solution**

# %% [markdown]
# ## Introduction
# Your team has been hired by the company X as data scientists. X makes gadgets for a wide range of industrial and commercial clients.
#
# As in-house data scientists, your teams first task, as per request from your new boss, is to optimize business operations. You have decided that a good first step would be to analyze the companys historical sales data to gain a better understanding of where profit is coming from. It may also reveal some low hanging fruit in terms of business opportunities.
#
# To get started, you have called the IT department to get access to the customer and sales transactions database. To your horror you've been told that such a database doens't exist, and the only record of sales transactions is kept by John from finance in an Excel spreadsheet. So you've emailed John asking for a CSV dump of the spreadsheet...
#
# In this project you need to clean the data you got from John, enrich it with further data, prepare a database for the data, and do some data analysis. The project is comprised of five parts. They are intended to be solved in the order they appear, but it is highly recommended that you read through all of them and devise an overall strategy before you start implementing anything.

# %% [markdown]
# ## Part 1: Cleaning the data
# John has emailed you the following link to the CSV dump you requested.
#
# - [transactions.csv](https://raw.githubusercontent.com/patrickcording/02807-comp-tools/master/docker/work/data/transactions.csv)
#
# It seems as though he has been a bit sloppy when keeping the records.
#
# In this part you should:
# - Explain what the data is
# - Clean it to prepare it for inserting into a database and doing data analysis

# %% [markdown]
# ---
# ### Solution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import sqlite3

file = "data/transactions.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#           part        company         country          city     price  \
# 0   54868-5165  Chatterbridge           Spain     Barcelona   784.79€
# 1   60505-2867           Lajo          Greece  Thessaloniki   187.99€
# 2    24385-268      Flipstorm          Greece        Athens   221.73€
# 3    76117-001    Twitterbeat          France        Annecy  1075.82€
# 4   44946-1046  Chatterbridge           Spain     Barcelona   412.55€
# 5    16729-167  Chatterbridge           Spain     Barcelona   359.52€
# 6    52125-444          Voomm          France         Paris   266.62€
# 7    43419-018       Buzzbean         Germany    Düsseldorf   103.45€
# 8    54092-515          Zooxo  United Kingdom        London   £704.94
# 9   24286-1562           Lajo          Greece  Thessaloniki   317.65€
# 10   49035-530      Flipstorm          Greece        Athens   841.97€
# 11  36987-1697    Brainsphere        Portugal         Braga   830.75€
# ...

# %% [markdown]
# The data is a CSV-file containing sales information from 2016-2019. The data has six columns of attributes (part, company, country, city, price, date). There might be errors within the data that we are not aware of, and so we will begin to clean the data.
#
# First, the city attribute was checked for errors.

# %%
df['city'].unique()
# Out:
# array(['Barcelona', 'Thessaloniki', 'Athens', 'Annecy', 'Paris',
#        'Düsseldorf', 'London', 'Braga', 'Nanterre', 'Amadora\t',
#        'New York', 'Arnhem', 'Nice', 'Lisbon', 'Amsterdam', 'Porto',
#        'Boston', 'Niihama', 'Almada', 'Aranhas', 'Heraklion', 'Amiens',
#        'Patras', 'Arcueil', 'Lyon', 'Asaka', 'Champagnole', 'Zürich', nan,
#        'Monção', 'Vila Fria'], dtype=object)

# %% [markdown]
# In the city column Amadora is consistently written as "Amadora\t". This is corrected to "Amadora".

# %%
df = df.replace(to_replace = 'Amadora\t', value = 'Amadora')

# %% [markdown]
# Then, the countries were investigated.

# %%
df['country'].unique()
# Out:
# array(['Spain', 'Greece', 'France', 'Germany', 'United Kingdom',
#        'Portugal', 'United States', 'Netherlands', 'Japan', 'Switzerland',
#        nan, 'US', 'Tyskland', 'Portuga'], dtype=object)

# %% [markdown]
# It was seen that there were several errors in the countries. These were mainly either danish names for the countries, non-values, or abbreviations. The observed errors were: nan, 'US', 'Tyskland', 'Portuga'. nan was corrected later.

# %%
to_replace = {'US': 'United States', 'Tyskland': 'Germany', 'Portuga': 'Portugal'}
df['country'].replace(to_replace, inplace=True)
df['country'].unique()
# Out:
# array(['Spain', 'Greece', 'France', 'Germany', 'United Kingdom',
#        'Portugal', 'United States', 'Netherlands', 'Japan', 'Switzerland',
#        nan], dtype=object)

# %% [markdown]
# Then the presence of missing values are checked in all columns.

# %%
df.isna().sum()
# Out:
# part         10
# company       0
# country    2171
# city         33
# price         1
# date          0
# dtype: int64

# %% [markdown]
# It was decided that the missing values for the different parts and prices would not possible to calculate, since the price of the same parts seemed to differ. Therefore, these entries were excluded from the data. 11 entries were removed.

# %%
df = df[~df.isna()['price']]
df = df[~df.isna()['part']]
df.isna().sum()
# Out:
# part          0
# company       0
# country    2171
# city         33
# price         0
# date          0
# dtype: int64

# %% [markdown]
# The next step was to fix the missing country and cities values. The incorrect values were initially printed.

# %%
df['company'].unique()
# Out:
# array(['Chatterbridge', 'Lajo', 'Flipstorm', 'Twitterbeat', 'Voomm',
#        'Buzzbean', 'Zooxo', 'Brainsphere', 'Thoughtmix', 'Wordify',
#        'Teklist', 'Avaveo', 'Ntags', 'Innojam', 'Shufflebeat', 'Zoonder',
#        'Kanoodle', 'Gabcube', 'Roodel', 'Riffpath', 'Eimbee', 'Yozio',
#        'Rhycero', 'Realpoint', 'Gabtune', 'Bubblemix', 'Gevee', 'Tagtune',
#        'Zooxo.', 'Laj0', 'Ntagz', ' -', ' a', 'aa', 'Thoughtmixz'],
#       dtype=object)

# %% [markdown]
# The list contains some mispellings, which are easily corrected for, but the company entries "aa", " a" and " -" had to be more thoroughly investigated. To gain more knowledge about these, their corresponding rows were printed.

# %%
print(df[df['company']== 'aa'])
print(df[df['company']== ' a'])
print(df[df['company']== ' -'])
# Out:
#             part company        country      city     price  \
# 13841  51346-145      aa  United States  New York  $1059.38
#
#                       date
# 13841  2017-12-16 20:02:15
#             part company        country      city   price                 date
# 13840  37205-992       a  United States  New York  $395.3  2017-12-16 18:59:53
#             part company        country    city     price                 date
# 13839  17156-617       -  United States  Boston  $1168.82  2017-12-16 17:55:55

# %% [markdown]
# It was observed that for the companies "aa", " a" and " -", they all only had one single sale. Therefore, it was concluded that the naming of the company was an error that needed correction. In order to do this, the cities where the wrongly-named companies made orders from was investigated to see which companies were from these cities.

# %%
print(df[df['city']=='New York']['company'].unique())
print(df[df['city']=='Boston']['company'].unique())
# Out:
# ['Wordify' ' a' 'aa']
# ['Zoonder' ' -']

# %% [markdown]
# It was observed that there was only one major customer in each city. It was therefore concluded that the sale to "aa" and " a" were to the company "Wordify" and the sale to " -" was to "Zoonder". The incorrect names were thus replaced with the correct ones, along with the misspelled ones.

# %%
to_replace = {'Zooxo.':'Zooxo', 'Laj0':'Lajo', 'Ntagz':'Ntags', ' -': 'Zoonder', ' a':'Wordify', 'aa':'Wordify', 'Thoughtmixz':'Thoughtmix'}
df['company'].replace(to_replace, inplace=True)
df['company'].unique()
# Out:
# array(['Chatterbridge', 'Lajo', 'Flipstorm', 'Twitterbeat', 'Voomm',
#        'Buzzbean', 'Zooxo', 'Brainsphere', 'Thoughtmix', 'Wordify',
#        'Teklist', 'Avaveo', 'Ntags', 'Innojam', 'Shufflebeat', 'Zoonder',
#        'Kanoodle', 'Gabcube', 'Roodel', 'Riffpath', 'Eimbee', 'Yozio',
#        'Rhycero', 'Realpoint', 'Gabtune', 'Bubblemix', 'Gevee', 'Tagtune'],
#       dtype=object)

# %% [markdown]
# Then the dataset was separated based on the presence of missing data. This was done to lower the processing time. The two datasets were to be joined afterwards.

# %%
df_na = df[df.isnull().any(1)]
df_drop = df.dropna()

# %% [markdown]
# The next step was to identify which companies had missing values in the country and city columns.
# A list of unique companies in the df_na dataset were defined and looped through.
# For each company, its occurances in df_drop were found and their most common country and city was stored in a dictionary. The cities and their occurances were printed to illustrate why we thought this was a valid approach.

# %%
companies = df_na['company'].unique()

comp_dict = {}
for company in companies:
    comp_dict[company] = dict()
    comp_dict[company]['city'] = df_drop[df_drop['company']==company]['city'].value_counts().index[0]
    comp_dict[company]['country'] = df_drop[df_drop['company']==company]['country'].value_counts().index[0]
    print(df_drop[df_drop['company']==company]['city'].value_counts())
# Out:
# Arnhem    387
# Name: city, dtype: int64
# Braga     1114
# Monção       1
# Name: city, dtype: int64
# Düsseldorf    1125
# Name: city, dtype: int64
# Porto    1382
# Name: city, dtype: int64
# Annecy    2037
# Name: city, dtype: int64
# Heraklion    130
# Name: city, dtype: int64
# Barcelona    1425
# Name: city, dtype: int64
# Lisbon    1353
# Name: city, dtype: int64
# Athens      713
# Nanterre    332
# Name: city, dtype: int64
# Amadora      2511
# Vila Fria       1
# Name: city, dtype: int64
# Aranhas    552
# Name: city, dtype: int64
# New York    858
# Name: city, dtype: int64
# Patras    583
# Name: city, dtype: int64
# Amiens    452
# Name: city, dtype: int64
# Almada    323
# Name: city, dtype: int64
# Boston    398
# Name: city, dtype: int64
# Paris    220
# Name: city, dtype: int64
# Nice    182
# Name: city, dtype: int64
# London    1511
# Name: city, dtype: int64
# Niihama    112
# Name: city, dtype: int64
# Asaka    47
# Name: city, dtype: int64
# Arcueil    180
# ...

# %% [markdown]
# All companies, except for 3, was found to have only one location from which they placed orders. Two of the three only had one occurance of the next most common city, while the third has around two thirds from its primary city. We therefore believe we can assume the missing cities are from the most common in the list above. The country is connected to the city, so the same approach can be used to set those. With the cases where a company ordered once from another city, it is not really possible to say if that is correct, or if either the company name or the location is incorrect, so it was decided to not do any correction there.
#
# Next, these found values were added to lists in order and inserted into the dataset. In order to do this in a simple way, the df_na indices were reset.
# To keep the same positions as the dataset, the current values were stored if they were not missing.

# %%
countries = list()
cities = list()

for comp, country, city in zip(df_na['company'], df_na['country'], df_na['city']):
    if str(city) == 'nan':
        cities.append(comp_dict[comp]['city'])
    else:
        cities.append(city)
    if str(country) == 'nan':
        countries.append(comp_dict[comp]['country'])
    else:
        countries.append(country)

df_na = df_na.reset_index(drop=True)
df_na['country'] = countries
df_na['city'] = cities

# %% [markdown]
# The two datasets were merged and the number of missing values were printed to see if something had been missed.

# %%
df_na
df = pd.concat([df_drop, df_na])
df.isna().sum()
# Out:
# part       0
# company    0
# country    0
# city       0
# price      0
# date       0
# dtype: int64

# %% [markdown]
# The dataset now contains no missing information.

# %% [markdown]
# ---
# ## Part 2: Enriching the data

# %% [markdown]
# A common task for a data scientists is to combine or enrich data from internal sources with data available from external sources. The purpose of this can be either to fix issues with the data or to make it easier to derive insights from the data.
#
# In this part you should enrich your data with data from at least one external source. You may look to part 4 for some  inspiration as to what is required. Your solution should be automated, i.e., you can not ask the reader of your notebook to download any data manually. You should argue why and what you expect to achieve by the enrichments you are doing.

# %% [markdown]
# ---
# ### Solution

# %% [markdown]
# To make the prices comparable, they were all converted to Euros and the € signs removed.
#
# Exchange rates were collected automatically from: "https://api.exchangeratesapi.io/latest".
#
# For some values the currency was missing. To solve this it was assumed that the 4 used currencies were USD, GBP, JPY, and EUR (This assumption was made based on the countries previously found). Thus, we checked the origin country and assigned the currency based on that information.

# %%
# Extract currency information and print result
r = requests.get('https://api.exchangeratesapi.io/latest')
json_resp = r.json()
json_resp
# Out:
# {'base': 'EUR',
#  'date': '2019-10-09',
#  'rates': {'AUD': 1.6282,
#   'BGN': 1.9558,
#   'BRL': 4.4783,
#   'CAD': 1.4607,
#   'CHF': 1.0927,
#   'CNY': 7.8265,
#   'CZK': 25.823,
#   'DKK': 7.4691,
#   'GBP': 0.8985,
#   'HKD': 8.6143,
#   'HRK': 7.427,
#   'HUF': 334.04,
#   'IDR': 15560.08,
#   'ILS': 3.8465,
#   'INR': 78.034,
#   'ISK': 137.3,
#   'JPY': 117.91,
#   'KRW': 1314.77,
#   'MXN': 21.452,
#   'MYR': 4.6087,
#   'NOK': 10.0528,
#   'NZD': 1.7381,
#   'PHP': 56.816,
#   'PLN': 4.3236,
#   'RON': 4.7486,
#   'RUB': 71.1918,
#   'SEK': 10.9173,
#   'SGD': 1.5153,
#   'THB': 33.311,
#   'TRY': 6.4053,
#   'USD': 1.0981,
#   'ZAR': 16.6248}}

# %% [markdown]
# The exchange rates for USD, GBP, and JPY were stored

# %%
JPY = json_resp['rates']['JPY']
USD = json_resp['rates']['USD']
GBP = json_resp['rates']['GBP']

# %% [markdown]
# These exchange rates were used to convert all prices to Euros.

# %%
price = df['price']
country = df['country']
new_price = list()

for val, cur in zip(price, country):
    if type(val) == float: #In case currency sign (€,$,£,¥) was missing from the price-value.
        if cur == 'Japan':
            val = val / JPY
        elif cur == 'United States':
            val = val / USD
        elif cur == 'United Kingdom':
            val = val / GBP
    elif val[0] == '$':
        val = float(val[1:]) / USD
    elif val[0] == '£':
        val = float(val[1:]) / GBP
    elif val[0] == '¥':
        val = float(val[1:]) / JPY
    elif val[-1] == '€':
        val = float(val[:-1])
    
    new_price.append(val)
df['price'] = new_price
df.head(10)
# Out:
#          part        company         country          city    price  \
# 0  54868-5165  Chatterbridge           Spain     Barcelona   784.79
# 1  60505-2867           Lajo          Greece  Thessaloniki   187.99
# 2   24385-268      Flipstorm          Greece        Athens   221.73
# 3   76117-001    Twitterbeat          France        Annecy  1075.82
# 4  44946-1046  Chatterbridge           Spain     Barcelona   412.55
# 5   16729-167  Chatterbridge           Spain     Barcelona   359.52
# 6   52125-444          Voomm          France         Paris   266.62
# 7   43419-018       Buzzbean         Germany    Düsseldorf   103.45
# 8   54092-515          Zooxo  United Kingdom        London  784.574
# 9  24286-1562           Lajo          Greece  Thessaloniki   317.65
#
#                   date
# 0  2016-01-02 00:01:05
# 1  2016-01-02 00:05:26
# 2  2016-01-02 00:18:30
# 3  2016-01-02 02:32:30
# 4  2016-01-02 04:51:55
# 5  2016-01-02 07:20:59
# 6  2016-01-02 07:40:37
# 7  2016-01-02 08:57:57
# ...

# %% [markdown]
# The currencies were thus all converted to Euros.
#
# Some of the dates had another format than others (dd/mm/yyyy and yyyy-mm-dd), and so they were all converted to the same format. In the cases of missing time values the time was set to 12:00:00.

# %%
years = list()
dates = list()
times = list()

for date in df['date']:
    if date[4]=='-':   # If format is yyyy-mm-dd
        years.append(date[:4])
        dates.append(date[5:10])
        times.append(date[11:])
    else:              # Else format is dd/mm/yyyy
        years.append(date[-4:])
        new_date = "{}-{}".format(date[3:5],date[:2])
        dates.append(new_date)
        times.append('12:00:00')
df['date'] = ["{}-{} {}".format(years[x], dates[x], times[x]) for x in range(len(years))]
df.head(20)
# Out:
#           part        company         country          city    price  \
# 0   54868-5165  Chatterbridge           Spain     Barcelona   784.79
# 1   60505-2867           Lajo          Greece  Thessaloniki   187.99
# 2    24385-268      Flipstorm          Greece        Athens   221.73
# 3    76117-001    Twitterbeat          France        Annecy  1075.82
# 4   44946-1046  Chatterbridge           Spain     Barcelona   412.55
# 5    16729-167  Chatterbridge           Spain     Barcelona   359.52
# 6    52125-444          Voomm          France         Paris   266.62
# 7    43419-018       Buzzbean         Germany    Düsseldorf   103.45
# 8    54092-515          Zooxo  United Kingdom        London  784.574
# 9   24286-1562           Lajo          Greece  Thessaloniki   317.65
# 10   49035-530      Flipstorm          Greece        Athens   841.97
# 11  36987-1697    Brainsphere        Portugal         Braga   830.75
# 12  44946-1046      Flipstorm          France      Nanterre    406.4
# ...

# %% [markdown]
# ---
# ## Part 3: Creating a database
# Storing data in a relational database has the advantages that it is persistent, fast to query, and it will be easier access for other employees at Weyland-Yutani.
#
# In this part you should:
# - Create a database and table(s) for the data
# - Insert data into the tables
#
# You may use SQLite locally to do this. You should argue why you choose to store your data the way you do.

# %% [markdown]
# ---
# ### Solution

# %% [markdown]
# Database was created and a connection established. In case the code should be re-run, a "drop table" command was implemented.

# %%
conn = sqlite3.connect('data/transactions.db')
c = conn.cursor()

# %%
c.execute('DROP TABLE IF EXISTS sales')
conn.commit()

# %% [markdown]
# In order to maintain the correct dtypes, a SQL table names "sales" was created and the dataframe was appended to it.

# %%
c.execute("""CREATE TABLE IF NOT EXISTS sales(id INTEGER PRIMARY KEY, part TEXT,
             company TEXT, country TEXT, city TEXT, price REAL, date TEXT)""")
conn.commit()

# %%
df.to_sql('sales', con = conn, if_exists = 'append', index = False)
conn.commit()

# %% [markdown]
# The database is now ready for analysis.

# %% [markdown]
# ---
# ## Part 4: Analyzing the data
# You are now ready to analyze the data. Your goal is to gain some actionable business insights to present to your boss.
#
# In this part, you should ask some questions and try to answer them based on the data. You should write SQL queries to retrieve the data. For each question, you should state why it is relevant and what you expect to find.
#
# To get you started, you should prepare answers to the following questions. You should add more questions.
# #### Who are the most profitable clients?
# Knowing which clients that generate the most revenue for the company will assist your boss in distributing customer service ressources.
#
# #### Are there any clients for which profit is declining?
# Declining profit from a specific client may indicate that the client is disatisfied with the product. Gaining a new client is often much more work than retaining one. Early warnings about declining profit may help your boss fighting customer churn.
#
#
# Remember, you are taking this to your new boss, so think about how you present the data.

# %% [markdown]
# ---
# ### Solution

# %% [markdown]
# The following plot lists the total sales for each of the company's clients.

# %%
c.execute('SELECT company, SUM(price) FROM sales GROUP BY company ORDER BY SUM(price) DESC')

plot = pd.DataFrame(c.fetchall(), columns = ['Company','price']).plot.bar(x='Company',y='price')
plot.set_ylabel('Total sales (€)')
plot.set_title('Total sales to customers')
plot

# %% [markdown]
# We see that Thoughtmix is most profitable client.
#
# The following plot illustrates which clients that have had declining business with our company.

# %%
command = '''
    SELECT company, SUM(price), SUBSTR(date,1,4) FROM sales
    GROUP BY company, SUBSTR(date,1,4)
'''
c.execute(command)
data = pd.DataFrame(c.fetchall(), columns = ['Company','price','Year'])
data_piv = data.pivot(index='Year', columns='Company', values='price')

for company in data['Company'].unique():
    if data_piv[company][0] < data_piv[company].dropna()[-1]:
        data_piv.drop(columns=company, inplace=True)
plot = data_piv.plot()
plot.set_ylabel('Sales per year (€)')
plot.set_title('Clients with declining business')
plot

# %% [markdown]
# We see that especially Flipstorm and Voomm have made fewer purchases in 2017 and 2018 than in 2016. Efforts to reclaim these clients will therefore be essential.
#
# The next table and plot shows which parts that are sold in greatest quantity. We thought this is relevant since it could provide great info for supply chain management and show which other parts maybe needs more careful marketing.

# %%
command = '''
    SELECT part, COUNT(*) FROM sales
    GROUP BY part
    ORDER BY COUNT(part) DESC
'''
c.execute(command)
data = pd.DataFrame(c.fetchall(), columns = ['Part','Count'])
plot = data.plot.bar(x='Part',y='Count')
plot.set_ylabel('Units sold')
plot.set_title('Display of number of units sold per part')
data.head(10)
# Out:
#          Part  Count
# 0   17156-617    300
# 1   37205-992    295
# 2   0268-6107    293
# 3   52959-433    293
# 4  54868-0823    292
# 5  62011-0219    291
# 6   51346-145    289
# 7   13537-259    287
# 8  58118-5060    286
# 9   10237-832    285

# %% [markdown]
# We see that the best selling part "only" outsells the lowest selling part by a factor of 3. The table could be expanded (by modifying the header input) if the ID of all the parts is to be showen (since it cannot be read from the graph).
#
# The following table and plot was made to determine the sales distribution based on the countries. We thought this could provide interesting knowledge into which emerging markets that the company could expand into.

# %%
command = '''
    SELECT country, SUM(price) FROM sales
    GROUP BY country
    ORDER BY SUM(price) DESC
'''
c.execute(command)
data = pd.DataFrame(c.fetchall(), columns = ['Country','Price (€)'])
plot = data.plot.bar(x='Country',y='Price (€)')
plot.set_ylabel('Total sales (€)')
plot.set_title('Sales per country')
data
# Out:
#           Country     Price (€)
# 0        Portugal  4.763407e+06
# 1          France  2.235683e+06
# 2          Greece  1.062999e+06
# 3  United Kingdom  9.522897e+05
# 4           Spain  9.193497e+05
# 5   United States  8.249672e+05
# 6         Germany  7.139126e+05
# 7     Netherlands  2.672517e+05
# 8           Japan  1.053832e+05
# 9     Switzerland  6.579640e+03

# %% [markdown]
# As it can be seen, Portugal is by far the largest market. Smaller markets, such as Switzerland and Japan are also very interesting, since they could potentially be markets that the company could tap into. With this knowledge, we thought it could be interesting to see which markets that has had the largest percentage-wise growth over the past 3 years.

# %%
command = '''
    SELECT country, SUM(price), SUBSTR(date,1,4) FROM sales
    GROUP BY country, SUBSTR(date,1,4)
'''
c.execute(command)

data = pd.DataFrame(c.fetchall(), columns = ['Country','price','Year'])
data_piv = data.pivot(index='Year', columns='Country', values='price').dropna()

for country in data['Country'].unique():
    dat = [(data_piv[country][x]/data_piv[country][x-1]) for x in range(1,len(data_piv[country]))]
    dat = (np.array([1] + dat)-1)*100
    data_piv[country] = dat
    if dat[0] > dat[-1]:
        data_piv.drop(columns=country, inplace=True)
    
plot = data_piv.plot()
plot.set_ylabel('% increase from the previous year')
plot.set_title('Country-wise market growth in %')

data_piv
# Out:
# Country    Germany  Netherlands     Spain  Switzerland
# Year
# 2016      0.000000     0.000000  0.000000     0.000000
# 2017      1.720827    -5.351542 -4.339380   253.001456
# 2018     11.429726    12.471480  5.240812    98.736902

# %% [markdown]
# We see above that there are 4 countries in which the company has seen growth from 2016-2019. Especially Switzerland is interesting, because it was also a market in which the company does not have a lot of business. Therefore our company should look into future oppertunities in this country aswell as perhaps Germany, The Netherlands, and Spain.

# %% [markdown]
# ---
# ## Part 5: Performance
# Your boss is very impressed with what you have achieved in less than two weeks, and he would like to take your idea of storing the customer and sales data in a relational database to production. However, John is concerned that the solution will not scale. His experience is telling him that you will see many occurrences of the following queries.
#
# - Show all sales to company X between time $t_1$ and time $t_2$
# - Show the latest X sales in the database
# - Show total sales per company per day
#
# Show that Johns concern is not justified.

# %% [markdown]
# Based on the occurences of queries that John has given us, we thought the best solution would be to index the database based on the date. This would allow for quick results when searching for resent sales, and it would also retain good performance when searching for sales by a specific company per day.

# %% [markdown]
# ---
# ### Solution

# %%
# An index is created
c.execute('CREATE INDEX ind ON sales(date)')
conn.commit()

# %%
column_names = ['index','part','company','country','city','price','date']

# %%
t1 = "2017-09-24 13:28:13"   # Insert starting day of interest
t2 = "2018-09-24 13:28:13"   # Insert ending day of interest
c.execute('SELECT * FROM sales WHERE date > ? AND date < ? ORDER BY date', (t1, t2))
pd.DataFrame(c.fetchall(), columns = column_names)
# Out:
#       index        part        company         country        city  \
# 0     10241  58118-5060       Buzzbean         Germany  Düsseldorf
# 1     10242  52380-1102          Zooxo  United Kingdom      London
# 2     10243  55566-2100        Zoonder   United States      Boston
# 3     10244  54868-0823  Chatterbridge           Spain   Barcelona
# 4     10245   59779-028          Ntags        Portugal      Lisbon
# ...     ...         ...            ...             ...         ...
# 6404  16610   0185-0373          Zooxo  United Kingdom      London
# 6405  16611   0268-1401          Ntags        Portugal      Lisbon
# 6406  16612   49349-842    Shufflebeat        Portugal       Porto
# 6407  16613  58118-5060  Chatterbridge           Spain   Barcelona
# 6408  16614   70253-307    Shufflebeat        Portugal       Porto
#
#             price                 date
# 0      251.810000  2017-09-24 16:10:12
# 1      414.858097  2017-09-24 16:54:30
# 2      252.099080  2017-09-24 17:08:15
# ...

# %% [markdown]
# The output lists all sales to company x in a DataFrame format to make it more readable.

# %% [markdown]
# ---

# %%
X = 10   # Latest X sales, adjust X as necessary
c.execute('SELECT * FROM sales ORDER BY date DESC')
pd.DataFrame(c.fetchall(), columns = column_names).head(X)
# Out:
#    index        part        company   country       city    price  \
# 0  18383   43419-018      Flipstorm    Greece     Athens   139.56
# 1  18382  49288-0285      Flipstorm    Greece     Athens  1051.08
# 2  18381   52343-025    Brainsphere  Portugal      Braga    686.1
# 3  18380   49999-737     Thoughtmix  Portugal    Amadora   828.37
# 4  18379   21695-267         Roodel  Portugal    Aranhas   606.37
# 5  18378   68462-565    Shufflebeat  Portugal      Porto   882.52
# 6  18377   98132-889          Yozio    Greece     Patras   179.88
# 7  18376  36987-1697  Chatterbridge     Spain  Barcelona  1017.44
# 8  18375   36800-952        Gabcube  Portugal     Almada   286.23
# 9  18374   13537-259     Thoughtmix  Portugal    Amadora   762.29
#
#                   date
# 0  2019-05-14 22:48:39
# 1  2019-02-21 20:05:00
# 2  2018-12-31 21:38:02
# 3  2018-12-31 21:24:17
# 4  2018-12-31 20:48:14
# 5  2018-12-31 19:56:53
# 6  2018-12-31 18:24:51
# 7  2018-12-31 16:46:06
# ...

# %% [markdown]
# Above are the latest 10 sales in the database.
#
# Next, we wanted to illustrate the total sales per company per day. We were unsure which way of displaying this would be most useful, so first all sale days and companies were listed. Each column is a company and each row represents a day with a sale.

# %%
command = '''
    SELECT company, SUM(price), SUBSTR(date,1,10) FROM sales
    GROUP BY company, SUBSTR(date,1,10)
'''
c.execute(command)
data = pd.DataFrame(c.fetchall(), columns = ['company','price','day'])
data_piv = data.pivot(index='day', columns='company', values='price')
data_piv.sort_index(inplace=True, ascending = False)
data_piv
# Out:
# company      Avaveo  Brainsphere  Bubblemix  Buzzbean  Chatterbridge  Eimbee  \
# day
# 2019-05-14      NaN          NaN        NaN       NaN            NaN     NaN
# 2019-02-21      NaN          NaN        NaN       NaN            NaN     NaN
# 2018-12-31      NaN       686.10        NaN    378.98        1017.44     NaN
# 2018-12-30      NaN       664.61        NaN   1177.83        3539.62     NaN
# 2018-12-29      NaN          NaN        NaN       NaN         794.20     NaN
# ...             ...          ...        ...       ...            ...     ...
# 2016-01-06   687.63       946.63        NaN   2233.76         522.49  789.66
# 2016-01-05      NaN       528.52        NaN    481.74        1218.88     NaN
# 2016-01-04      NaN       948.34        NaN    356.11        1380.53     NaN
# 2016-01-03  1029.92          NaN        NaN    272.06         304.59     NaN
# 2016-01-02      NaN      1429.27        NaN    103.45        1556.86     NaN
#
# ...

# %% [markdown]
# The output is not incredebly easy to get an overview over, so it was decided to show the same data, but company specific. So one should specify which company is of interest. Flipstorm is used as an example.

# %%
c.execute('SELECT * FROM sales WHERE company = "Flipstorm" ORDER BY date DESC')
pd.DataFrame(c.fetchall(), columns = column_names).head(10)
# Out:
#    index        part    company country      city    price  \
# 0  18383   43419-018  Flipstorm  Greece    Athens   139.56
# 1  18382  49288-0285  Flipstorm  Greece    Athens  1051.08
# 2  17629   52959-433  Flipstorm  France  Nanterre   340.64
# 3  16457   52125-136  Flipstorm  Greece    Athens   702.70
# 4  16117   67544-356  Flipstorm  Greece    Athens   791.44
# 5  15967   0268-1128  Flipstorm  Greece    Athens  1254.21
# 6  15800  62742-4030  Flipstorm  Greece    Athens   539.41
# 7  15135   16590-177  Flipstorm  Greece    Athens  1210.92
# 8  13697  52380-1102  Flipstorm  Greece    Athens   505.58
# 9  13428   49349-842  Flipstorm  Greece    Athens   340.52
#
#                   date
# 0  2019-05-14 22:48:39
# 1  2019-02-21 20:05:00
# 2  2018-11-19 04:51:50
# 3  2018-09-15 01:10:24
# 4  2018-08-25 20:57:43
# 5  2018-08-17 23:37:10
# 6  2018-08-08 02:29:06
# 7  2018-06-30 20:35:45
# 8  2018-04-11 02:28:46
# 9  2018-03-27 05:01:16

# %% [markdown]
# Above are the last 10 individual sales for a given company (Flipstorm) shown.
#
# Perhaps an equally as interesting thing to find is all sales occuring on a specific day. This is achieved by specifying a day of interest on the second line in the command. It should be noted that not all days give a result, as company x does not have a sale every single day.

# %%
command = '''
    SELECT part, company, country, city, SUM(price), date FROM sales
    WHERE SUBSTR(date,1,10) = "2016-01-03"
    GROUP BY company
    ORDER BY SUM(price) DESC
'''
c.execute(command)
pd.DataFrame(c.fetchall(), columns = column_names[1:])
# Out:
#           part        company         country        city        price  \
# 0   61398-0828      Flipstorm          Greece      Athens  5010.310000
# 1   54868-0823     Thoughtmix        Portugal     Amadora  1431.090000
# 2    37205-992    Shufflebeat        Portugal       Porto  1396.190000
# 3   54868-5165        Teklist     Netherlands      Arnhem  1146.660000
# 4    70253-307         Avaveo          France        Nice  1029.920000
# 5    49349-471          Voomm          France       Paris   842.930000
# 6    51079-947        Zoonder   United States      Boston   761.943357
# 7    67544-356          Zooxo  United Kingdom      London   670.417362
# 8    62756-707          Ntags        Portugal      Lisbon   322.450000
# 9    68233-011  Chatterbridge           Spain   Barcelona   304.590000
# 10   98132-889       Buzzbean         Germany  Düsseldorf   272.060000
# 11   0268-1604        Innojam     Netherlands   Amsterdam   157.220000
#
#                    date
# ...

# %% [markdown]
# Thus the total sales per client on a given day can be displayed.
#
# Storing the data in a relational database indexed on date allows for incredibly rapid searches and sortings based on date. Therefore, the major valid concern John should have is related to storing of the data, as indexing does increase the required storing capacity. In this particular case, it was increased from 1.5 MB to 2.0 MB.

# %%
conn.close()
